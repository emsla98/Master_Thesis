# %% [markdown]
# # Experiment 4: PCA Comparisons (Surface Elevation)
#
# In this experiment we will use two datasets:
#
# First dataset:
# - (Available) Training data: 11 months
# - Testing data: 1 month
#
# Second dataset:
# - (Available) Training data: 6 months
# - Testing data: 6 months
#
# Using these datasets we will look at the reconstruction error of the PCA models with 100 components, but fitted using different temporal periods.

# %% [markdown]
# ### Imports:

# %%
# %matplotlib notebook

# %%
# Import packages:
import mikeio
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os
import sys
import pandas as pd 
import seaborn as sns
import pickle as pkl


sys.path.append("../")
plt.style.use("seaborn-v0_8-whitegrid")

from Scripts import my_functions as mf

from mikeio.eum import EUMUnit
from PIL import Image
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, IncrementalPCA
from IPython.display import HTML
from tqdm import tqdm

# %% [markdown]
# ### Data Extraction

# %%
## Find the relative path to Data/DHI_wk_sim/Area.dfsu from current directory:

# Go up two levels from current directory:
path = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))

# Overwrite path:
path = os.path.join(path, "Data/DHI_yr_sim/Area.dfsu")

# Get first and last time step:
time = mikeio.open(path).time

# Load data (2 min):
data = mikeio.read(path,
                   time=slice("1997-01-01 00:00:00",
                              "1998-01-01 00:00:00"),
                   items="Surface elevation")

# %%
data
# Out:
# <mikeio.Dataset>
# dims: (time:17519, element:17980)
# time: 1997-01-01 00:00:00 - 1997-12-31 23:00:00 (17519 records)
# geometry: Dfsu2D (17980 elements, 10460 nodes)
# items:
#   0:  Surface elevation <Surface Elevation> (meter)

# %% [markdown]
# ### Models:

# %%
# Super class for models:
class myModels():
    
    def __init__(self):
        pass
    
    # Templates:
    class ModelTemplate:
        """
        Ensures that the methods fit, predict, and fit_predict are 
        instantiated for all classes based on this template.
        """

        def fit(self, X, y=None):
            raise NotImplementedError("fit method must be implemented in subclass")

        def predict(self, X):
            raise NotImplementedError("predict method must be implemented in subclass")

        def fit_predict(self, X, y=None):
            self.fit(X, y)
            return self.predict(X)
        
    class IPCA(ModelTemplate):

        def __init__(self, n_components=None):
            self.n_components = n_components
            self.model = IncrementalPCA(n_components=self.n_components,
                                        batch_size=self.n_components)

        def fit(self, X, y=None):
            self.model.fit(X, y)
            return self

        def predict(self, X):
            X = self.model.transform(X)
            return self.model.inverse_transform(X)
        
    class PCA(ModelTemplate):
        
        def __init__(self, n_components=None):
            self.n_components = n_components
            self.model = PCA(n_components=self.n_components)

        def fit(self, X, y=None):
            self.model.fit(X, y)
            return self

        def predict(self, X):
            X = self.model.transform(X)
            return self.model.inverse_transform(X)

# %% [markdown]
# ## Data split: (11 months training data. 1 month test data.)

# %%
# Split data into training and test sets:
z_train = data.Surface_elevation.sel(time=slice("1997-01-01 00:00:00",
                                                "1997-12-01 00:00:00")).values

z_test = data.Surface_elevation.sel(time=slice("1997-12-01 00:00:00",
                                               "1998-01-01 00:00:00")).values

# %% [markdown]
# ### Samples:

# %%
# First week, week-sized random sample, and week-sized systematic sample:
wk_1 = range(0, 48*7); np.random.seed(42)
wk_random = np.random.choice(range(0, z_train.shape[0]), 48*7, replace=False)
wk_system = np.linspace(0, z_train.shape[0]-1, 48*7, dtype=int)

# First month, month-sized random sample, and month-sized systematic sample:
mth_1 = range(0, 48*7*4)
mth_random = np.random.choice(range(0, z_train.shape[0]), 48*7*4, replace=False)
mth_system = np.linspace(0, z_train.shape[0]-1, 48*7*4, dtype=int)

# First three months, three-month-sized random sample, and three-month-sized systematic sample:
mth_3 = range(0, 48*7*4*3)
mth_3_random = np.random.choice(range(0, z_train.shape[0]), 48*7*4*3, replace=False)
mth_3_system = np.linspace(0, z_train.shape[0]-1, 48*7*4*3, dtype=int)

# %%
# Sample indices:
sample_ids = [wk_1, wk_random, wk_system,
              mth_1, mth_random, mth_system,
              mth_3, mth_3_random, mth_3_system]

# %% [markdown]
# ### Results

# %%
# Auxilliary variable:
compute = 1

# Try to load results from earlier runs:
if 1:

    # Load scalers and pcas if they exist:
    if os.path.exists("../Data_Results/Exp_4_scalers.pkl") and \
        os.path.exists("../Data_Results/Exp_4_pcas.pkl"):
        
        # Load scalers:
        with open("../Data_Results/Exp_4_scalers.pkl", "rb") as f:
            scalers = pkl.load(f)

        # Load pcas:
        with open("../Data_Results/Exp_4_pcas.pkl", "rb") as f:
            pcas = pkl.load(f)

        # Set compute to 0:
        compute = 0

print(f"compute = {compute}")
# Out:
# compute = 0

# %%
# Compute scalers and pcas (+16 min):
if compute:

    # Lists for scalers and pcas:
    scalers = [];  pcas = []

    for i in range(len(sample_ids)):
        
        print(f"Sample {i+1} of {len(sample_ids)}", end="\r")

        # Pick data:
        z_data = z_train[sample_ids[i]]

        # Create scaler:
        scaler = StandardScaler()

        # Fit scaler:
        scaler.fit(z_data)

        # Scale data:
        z_data_scaled = scaler.transform(z_data)

        # Create pca:
        pca = myModels.IPCA(n_components=100)

        # Fit pca:
        pca.fit(z_data_scaled)

        # Append scalers and pcas:
        scalers.append(scaler)
        pcas.append(pca)

# %%
# Save scalers and pcas (in Coding/Data_Results):
if compute:
    
    with open("../Data_Results/Exp_4_scalers.pkl", "wb") as f:
        pkl.dump(scalers, f)

    with open("../Data_Results/Exp_4_pcas.pkl", "wb") as f:
        pkl.dump(pcas, f)

# %%
def reconstruct(data, scaler, pca, batch_size=1000):
    """
    Reconstructs data using scaler and pca.
    """

    if data.shape[0] < batch_size:
        data_scaled = scaler.transform(data)
        data_scaled_recon = pca.predict(data_scaled)
        data_recon = scaler.inverse_transform(data_scaled_recon)

    else:
        data_recon = np.zeros(data.shape)
        for i in range(0, data.shape[0], batch_size)[:-1]:

            data_scaled = scaler.transform(data[i:i+batch_size])
            data_scaled_recon = pca.predict(data_scaled)
            
            data_recon[i:i+batch_size] = \
                scaler.inverse_transform(data_scaled_recon)

        data_scaled = scaler.transform(data[i+batch_size:])
        data_scaled_recon = pca.predict(data_scaled)
        data_recon[i+batch_size:] = scaler.inverse_transform(data_scaled_recon)

    return data_recon

# %%
# Auxilliary variable:
compute = 1

# Try to load results from earlier runs:
if 1:

    # Load results if they exist:
    if os.path.exists("../Data_Results/Exp_4_recon_errors.pkl"):

        # Load results:
        with open("../Data_Results/Exp_4_recon_errors.pkl", "rb") as f:
            recon_errors = pkl.load(f)
        
        # Extract results:
        fit_recon_errors, train_recon_errors, test_recon_errors = recon_errors
        
        # Set compute to 0:
        compute = 0

print(f"compute = {compute}")
# Out:
# compute = 1

# %%
# Only used to compute reconstruction errors: (~ 4 min)
if compute:

    # Allocate lists:
    fit_recon_errors = []; train_recon_errors = []; test_recon_errors = []

    # Compute reconstruction errors:
    for i in range(len(sample_ids)):
        
        print(f"Reconstructing sample {i+1} of {len(sample_ids)}", end="\r")

        # Fitting data:
        z_fit = z_train[sample_ids[i]]
        
        # Loop over data:
        for j, z_data in enumerate([z_fit, z_train, z_test]):

            # Reconstruct data:
            z_data_recon = reconstruct(z_data, scalers[i], pcas[i])

            # Compute reconstruction errors:
            recon_error = mf.rmse(z_data, z_data_recon, axis=1).mean()

            # Append reconstruction errors:
            if j == 0:
                fit_recon_errors.append(recon_error)
            elif j == 1:
                train_recon_errors.append(recon_error)
            else:
                test_recon_errors.append(recon_error)
# Out:
# Reconstructing sample 9 of 9

# %%
# Save results (in Coding/Data_Results):
if compute:

    # Combine errors:
    recon_errors = [fit_recon_errors, train_recon_errors, test_recon_errors]

    # Save results:
    with open("../Data_Results/Exp_4_recon_errors.pkl", "wb") as f:
        pkl.dump(recon_errors, f)

# %%
# Create dataframe with average RMSEs:
df = pd.DataFrame({
    "PCA": ["First week", "Week-sized random sample", 
            "Week-sized systematic sample",
            "First month", "Month-sized random sample", 
            "Month-sized systematic sample",
            "First three months", "Three-month-sized random sample",
            "Three-month-sized systematic sample",],
    "Fit RMSE": fit_recon_errors,
    "Train RMSE": train_recon_errors,
    "Test RMSE": test_recon_errors})

# %%
# Copy into Powerpoint:
df.round(6)
# Out:
#                                    PCA  Fit RMSE  Train RMSE  Test RMSE
# 0                           First week  0.000019    0.000272   0.000228
# 1             Week-sized random sample  0.000062    0.000100   0.000110
# 2         Week-sized systematic sample  0.000065    0.000101   0.000113
# 3                          First month  0.000049    0.000126   0.000119
# 4            Month-sized random sample  0.000079    0.000086   0.000096
# 5        Month-sized systematic sample  0.000079    0.000085   0.000096
# 6                   First three months  0.000077    0.000092   0.000102
# 7      Three-month-sized random sample  0.000081    0.000083   0.000093
# 8  Three-month-sized systematic sample  0.000082    0.000083   0.000093

# %% [markdown]
# ### Visualizations

# %%
plot_obj = data.Surface_elevation[0].copy()

plot_obj.item.unit = EUMUnit.millimeter

# %%
# Create subplot (1 by 3):
fig, axs = plt.subplots(1, 3, figsize=(15,6))

labels = ["1 Week", "1 Month", "3 Months"]

# Loop slices to test:
for i, test_slice in enumerate([z_test.shape[0]-1]):

    # Loop over time-scales:
    for j, scale in enumerate([2,5,8]):

        z_slice = z_test[test_slice].reshape(1, -1)
        z_slice_recon = reconstruct(z_slice, scalers[scale], pcas[scale])

        plot_obj.values = (z_slice - z_slice_recon).reshape(-1) * 1000

        cmap_max = np.quantile(np.abs(plot_obj.values), 0.99)
        digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
        cmap_max = np.round(cmap_max, digits)

        plot_obj.plot(ax=axs[j], cmap="seismic",
                      title=f"\nTest snapshot: {test_slice} - Training snapshots: {labels[j]}\n",
                      vmin=-cmap_max, vmax=cmap_max)


fig.suptitle("Visualization of reconstruction differences (Train-Test Ratio: 11:1)", fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Save figure:
fig.savefig("../Figures/Exp_4_recon_diffs1.png", dpi=100)

# %% [markdown]
# ## Data split: (6 months training data. 6 month test data.)

# %%
# Split data into training and test sets:
z_train2 = data.Surface_elevation.sel(time=slice("1997-01-01 00:00:00",
                                                "1997-07-01 00:00:00")).values

z_test2 = data.Surface_elevation.sel(time=slice("1997-07-01 00:00:00",
                                               "1998-01-01 00:00:00")).values

# %% [markdown]
# ### Samples:

# %%
# First week, week-sized random sample, and week-sized systematic sample:
wk_1 = range(0, 48*7); np.random.seed(42)
wk_random = np.random.choice(range(0, z_train2.shape[0]), 48*7, replace=False)
wk_system = np.linspace(0, z_train2.shape[0]-1, 48*7, dtype=int)

# First month, month-sized random sample, and month-sized systematic sample:
mth_1 = range(0, 48*7*4)
mth_random = np.random.choice(range(0, z_train2.shape[0]), 48*7*4, replace=False)
mth_system = np.linspace(0, z_train2.shape[0]-1, 48*7*4, dtype=int)

# First three months, three-month-sized random sample, and three-month-sized systematic sample:
mth_3 = range(0, 48*7*4*3)
mth_3_random = np.random.choice(range(0, z_train2.shape[0]), 48*7*4*3, replace=False)
mth_3_system = np.linspace(0, z_train2.shape[0]-1, 48*7*4*3, dtype=int)

# %%
# Sample indices:
sample_ids = [wk_1, wk_random, wk_system,
              mth_1, mth_random, mth_system,
              mth_3, mth_3_random, mth_3_system]

# %% [markdown]
# ### Results

# %%
# Auxilliary variable:
compute = 1

# Try to load results from earlier runs:
if 1:

    # Load scalers and pcas if they exist:
    if os.path.exists("../Data_Results/Exp_4_scalers2.pkl") and \
        os.path.exists("../Data_Results/Exp_4_pcas2.pkl"):
        
        # Load scalers:
        with open("../Data_Results/Exp_4_scalers2.pkl", "rb") as f:
            scalers2 = pkl.load(f)

        # Load pcas:
        with open("../Data_Results/Exp_4_pcas2.pkl", "rb") as f:
            pcas2 = pkl.load(f)

        # Set compute to 0:
        compute = 0

print(f"compute = {compute}")
# Out:
# compute = 0

# %%
# Compute scalers and pcas (~ 6 min):
if compute:

    # Lists for scalers and pcas:
    scalers2 = [];  pcas2 = []

    for i in range(len(sample_ids)):
        
        print(f"Sample {i+1} of {len(sample_ids)}", end="\r")

        # Pick data:
        z_data = z_train2[sample_ids[i]]

        # Create scaler:
        scaler = StandardScaler()

        # Fit scaler:
        scaler.fit(z_data)

        # Scale data:
        z_data_scaled = scaler.transform(z_data)

        # Create pca:
        pca = myModels.IPCA(n_components=100)

        # Fit pca:
        pca.fit(z_data_scaled)

        # Append scalers and pcas:
        scalers2.append(scaler)
        pcas2.append(pca)

# %%
# Save scalers and pcas (in Coding/Data_Results):
if compute:
    with open("../Data_Results/Exp_4_scalers2.pkl", "wb") as f:
        pkl.dump(scalers2, f)

    with open("../Data_Results/Exp_4_pcas2.pkl", "wb") as f:
        pkl.dump(pcas2, f)

# %%
def reconstruct(data, scaler, pca, batch_size=1000):
    """
    Reconstructs data using scaler and pca.
    """

    if data.shape[0] < batch_size:
        data_scaled = scaler.transform(data)
        data_scaled_recon = pca.predict(data_scaled)
        data_recon = scaler.inverse_transform(data_scaled_recon)

    else:
        data_recon = np.zeros(data.shape)
        for i in range(0, data.shape[0], batch_size)[:-1]:

            data_scaled = scaler.transform(data[i:i+batch_size])
            data_scaled_recon = pca.predict(data_scaled)
            
            data_recon[i:i+batch_size] = \
                scaler.inverse_transform(data_scaled_recon)

        data_scaled = scaler.transform(data[i+batch_size:])
        data_scaled_recon = pca.predict(data_scaled)
        data_recon[i+batch_size:] = scaler.inverse_transform(data_scaled_recon)

    return data_recon

# %%
# Auxilliary variable:
compute = 1

# Try to load results from earlier runs:
if 1:

    # Load results if they exist:
    if os.path.exists("../Data_Results/Exp_4_recon_errors2.pkl"):

        # Load results:
        with open("../Data_Results/Exp_4_recon_errors2.pkl", "rb") as f:
            recon_errors2 = pkl.load(f)
        
        # Extract results:
        fit_recon_errors2, train_recon_errors2, test_recon_errors2 = \
            recon_errors2

        # Set compute to 0:
        compute = 0

print(f"compute = {compute}")
# Out:
# compute = 1

# %%
# Only used for computing reconstruction errors: (~6 min)
if compute:

    # Allocate lists:
    fit_recon_errors2 = []; train_recon_errors2 = []; test_recon_errors2 = []

    # Compute reconstruction errors:
    for i in range(len(sample_ids)):
        
        print(f"Reconstructing sample {i+1} of {len(sample_ids)}", end="\r")

        # Fitting data:
        z_fit = z_train2[sample_ids[i]]
        
        # Loop over data:
        for j, z_data in enumerate([z_fit, z_train2, z_test2]):

            # Reconstruct data:
            z_data_recon = reconstruct(z_data, scalers2[i], pcas2[i])

            # Compute reconstruction errors:
            recon_error = mf.rmse(z_data, z_data_recon, axis=1).mean()

            # Append reconstruction errors:
            if j == 0:
                fit_recon_errors2.append(recon_error)
            elif j == 1:
                train_recon_errors2.append(recon_error)
            else:
                test_recon_errors2.append(recon_error)
# Out:
# Reconstructing sample 9 of 9

# %%
# Save results (in Coding/Data_Results):
if compute:

    # Combine errors:
    recon_errors2 = \
        [fit_recon_errors2, train_recon_errors2, test_recon_errors2]

    # Save results:
    with open("../Data_Results/Exp_4_recon_errors2.pkl", "wb") as f:
        pkl.dump(recon_errors2, f)

# %%
# Create dataframe with average RMSEs:
df2 = pd.DataFrame({
    "PCA": ["First week", "Week-sized random sample", 
            "Week-sized systematic sample",
            "First month", "Month-sized random sample", 
            "Month-sized systematic sample",
            "First three months", "Three-month-sized random sample",
            "Three-month-sized systematic sample",],
    "Fit RMSE": fit_recon_errors2,
    "Train RMSE": train_recon_errors2,
    "Test RMSE": test_recon_errors2})

# %%
# Copy to Powerpoint:
df2.round(6)
# Out:
#                                    PCA  Fit RMSE  Train RMSE  Test RMSE
# 0                           First week  0.000019    0.000284   0.000252
# 1             Week-sized random sample  0.000062    0.000100   0.000107
# 2         Week-sized systematic sample  0.000065    0.000100   0.000106
# 3                          First month  0.000049    0.000127   0.000123
# 4            Month-sized random sample  0.000079    0.000087   0.000094
# 5        Month-sized systematic sample  0.000080    0.000085   0.000093
# 6                   First three months  0.000077    0.000089   0.000097
# 7      Three-month-sized random sample  0.000081    0.000083   0.000091
# 8  Three-month-sized systematic sample  0.000082    0.000083   0.000091

# %% [markdown]
# ### Visualizations

# %%
plot_obj = data.Surface_elevation[0].copy()

plot_obj.item.unit = EUMUnit.millimeter

# %%
# Create subplot (1 by 3):
fig2, axs2 = plt.subplots(1, 3, figsize=(15,6))

labels = ["1 Week", "1 Month", "3 Months"]

# Loop slices to test:
for i, test_slice in enumerate([z_test2.shape[0]-1]):

    # Loop over time-scales:
    for j, scale in enumerate([2,5,8]):

        z_slice = z_test2[test_slice].reshape(1, -1)
        z_slice_recon = reconstruct(z_slice, scalers2[scale], pcas2[scale])

        plot_obj.values = (z_slice - z_slice_recon).reshape(-1) * 1000

        cmap_max = np.quantile(np.abs(plot_obj.values), 0.99)
        digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
        cmap_max = np.round(cmap_max, digits)

        plot_obj.plot(ax=axs2[j], cmap="seismic",
                      title=f"\nTest snapshot: {test_slice} - Training snapshots: {labels[j]}\n",
                      vmin=-cmap_max, vmax=cmap_max)


fig2.suptitle("Visualization of reconstruction differences (Train-Test Ratio: 1:1)", fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Save figure:
fig2.savefig("../Figures/Exp_4_recon_diffs2.png", dpi=100)

# %% [markdown]
# ## Extras

# %% [markdown]
# ### Plot of principal components

# %%
# Choose whether to re-visualize individual PCs:
if 0:

    # Define principal component ids:
    pcs = range(100)

    # Define plot object:
    plot_obj = data.Surface_elevation[0].copy()
    plot_obj.item.unit = EUMUnit.meter

    # Extract principal components:
    princomps = np.array(pcas2[-1].model.components_)

    # Loop over pcs: (~ 4 min)
    for pc in pcs:

        fig3 = plt.figure(num=0, figsize=(6, 4.8), dpi=100)
        axs3 = fig3.add_subplot(111)

        # Print status:
        print(f"Visualizing principal component {pc+1} of {len(pcs)}")

        # Set plot object values:
        plot_obj.values = princomps[pc]

        # Maximum value:
        cmap_max = np.quantile(np.abs(plot_obj.values), 0.99)
        digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
        cmap_max = np.round(cmap_max, digits)

        # Plot:
        plot_obj.plot(ax=axs3,
                      title=f"Principal Component {pc+1}", cmap="seismic",
        vmin=-cmap_max, vmax=cmap_max)


        # Save figure:
        fig3.savefig(f"../Figures/Exp_4_pcs/Exp_4_pc{pc+1}.png")

        plt.close(fig3)
# Out:
# Visualizing principal component 1 of 100
# Visualizing principal component 2 of 100
# Visualizing principal component 3 of 100
# Visualizing principal component 4 of 100
# Visualizing principal component 5 of 100
# Visualizing principal component 6 of 100
# Visualizing principal component 7 of 100
# Visualizing principal component 8 of 100
# Visualizing principal component 9 of 100
# Visualizing principal component 10 of 100
# Visualizing principal component 11 of 100
# Visualizing principal component 12 of 100
# Visualizing principal component 13 of 100
# Visualizing principal component 14 of 100
# Visualizing principal component 15 of 100
# Visualizing principal component 16 of 100
# Visualizing principal component 17 of 100
# Visualizing principal component 18 of 100
# Visualizing principal component 19 of 100
# Visualizing principal component 20 of 100
# Visualizing principal component 21 of 100
# Visualizing principal component 22 of 100
# Visualizing principal component 23 of 100
# Visualizing principal component 24 of 100
# Visualizing principal component 25 of 100
# Visualizing principal component 26 of 100
# Visualizing principal component 27 of 100
# Visualizing principal component 28 of 100
# Visualizing principal component 29 of 100
# Visualizing principal component 30 of 100
# Visualizing principal component 31 of 100
# Visualizing principal component 32 of 100
# Visualizing principal component 33 of 100
# Visualizing principal component 34 of 100
# Visualizing principal component 35 of 100
# Visualizing principal component 36 of 100
# Visualizing principal component 37 of 100
# Visualizing principal component 38 of 100
# Visualizing principal component 39 of 100
# Visualizing principal component 40 of 100
# Visualizing principal component 41 of 100
# Visualizing principal component 42 of 100
# Visualizing principal component 43 of 100
# Visualizing principal component 44 of 100
# Visualizing principal component 45 of 100
# Visualizing principal component 46 of 100
# Visualizing principal component 47 of 100
# Visualizing principal component 48 of 100
# Visualizing principal component 49 of 100
# Visualizing principal component 50 of 100
# Visualizing principal component 51 of 100
# Visualizing principal component 52 of 100
# Visualizing principal component 53 of 100
# Visualizing principal component 54 of 100
# Visualizing principal component 55 of 100
# Visualizing principal component 56 of 100
# Visualizing principal component 57 of 100
# Visualizing principal component 58 of 100
# Visualizing principal component 59 of 100
# Visualizing principal component 60 of 100
# Visualizing principal component 61 of 100
# Visualizing principal component 62 of 100
# Visualizing principal component 63 of 100
# Visualizing principal component 64 of 100
# Visualizing principal component 65 of 100
# Visualizing principal component 66 of 100
# Visualizing principal component 67 of 100
# Visualizing principal component 68 of 100
# Visualizing principal component 69 of 100
# Visualizing principal component 70 of 100
# Visualizing principal component 71 of 100
# Visualizing principal component 72 of 100
# Visualizing principal component 73 of 100
# Visualizing principal component 74 of 100
# Visualizing principal component 75 of 100
# Visualizing principal component 76 of 100
# Visualizing principal component 77 of 100
# Visualizing principal component 78 of 100
# Visualizing principal component 79 of 100
# Visualizing principal component 80 of 100
# Visualizing principal component 81 of 100
# Visualizing principal component 82 of 100
# Visualizing principal component 83 of 100
# Visualizing principal component 84 of 100
# Visualizing principal component 85 of 100
# Visualizing principal component 86 of 100
# Visualizing principal component 87 of 100
# Visualizing principal component 88 of 100
# Visualizing principal component 89 of 100
# Visualizing principal component 90 of 100
# Visualizing principal component 91 of 100
# Visualizing principal component 92 of 100
# Visualizing principal component 93 of 100
# Visualizing principal component 94 of 100
# Visualizing principal component 95 of 100
# Visualizing principal component 96 of 100
# Visualizing principal component 97 of 100
# Visualizing principal component 98 of 100
# Visualizing principal component 99 of 100
# Visualizing principal component 100 of 100

# %% [markdown]
# ### Combining images into grids

# %%
# Set the dimensions of the grid
columns = 5
rows = 4

# Set the dimensions of each image
width = 600
height = 480

# Create a new image to hold the grid
grid = Image.new('RGB', (columns*width, rows*height))

# Loop over 5 images:
for k in range(5):

    # Set count:
    count = k*20

    # Loop through each image and paste it onto the grid
    for j in range(rows):
        for i in range(columns):

            count += 1

            # Open the image
            image_path = f"../Figures/Exp_4_pcs/Exp_4_pc{count}.png"
            image = Image.open(image_path)
            
            # Calculate the position to paste the image
            x = i * width
            y = j * height
            
            # Paste the image onto the grid
            grid.paste(image, (x, y))

    # Save the grid image
    grid.save(f'../Figures/Exp_4_{k*20+1}-{(k+1)*20}pc.png')
