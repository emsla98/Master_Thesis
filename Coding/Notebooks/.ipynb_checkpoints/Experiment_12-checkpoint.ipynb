# %% [markdown]
# # Experiment 12: PCA on full dataset (Surface Elevation, U- and V-velocity)

# %% [markdown]
# ## Imports

# %%
# %matplotlib notebook

# %%
# Import packages:
import mikeio
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os
import sys
import pickle as pkl

sys.path.append("../")
plt.style.use("seaborn-v0_8-whitegrid")

from Scripts import my_functions as mf

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, IncrementalPCA
from IPython.display import HTML
from tqdm import tqdm

# %% [markdown]
# ## Data Extraction

# %%
## Find the relative path to Data/DHI_wk_sim/Area.dfsu from current directory:

# Go up two levels from current directory:
path = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))

# Overwrite path:
path = os.path.join(path, "Data/DHI_yr_sim/Area.dfsu")

print(mikeio.open(path))

# Get first and last time step:
time = mikeio.open(path).time

# Load data: (~ 3.5 min)
data = mikeio.read(path,
                   time=slice(time[48], time[-1]),
                   items=["Surface elevation",
                          "U velocity",
                          "V velocity"])
# Out:
# Dfsu2D
# number of elements: 17980
# number of nodes: 10460
# projection: LONG/LAT
# items:
#   0:  Surface elevation <Surface Elevation> (meter)
#   1:  Total water depth <Water Depth> (meter)
#   2:  U velocity <u velocity component> (meter per sec)
#   3:  V velocity <v velocity component> (meter per sec)
# time: 18191 steps with dt=1800.0s
#       1996-12-18 00:00:00 -- 1997-12-31 23:00:00

# %%
data
# Out:
# <mikeio.Dataset>
# dims: (time:18143, element:17980)
# time: 1996-12-19 00:00:00 - 1997-12-31 23:00:00 (18143 records)
# geometry: Dfsu2D (17980 elements, 10460 nodes)
# items:
#   0:  Surface elevation <Surface Elevation> (meter)
#   1:  U velocity <u velocity component> (meter per sec)
#   2:  V velocity <v velocity component> (meter per sec)

# %%
# Get surface elevation values:
data_vals = \
    np.concatenate([data[0].values, data[1].values, data[2].values],
                   axis=1)

# %% [markdown]
# ## Full PCA

# %%
# Auxilliary variable:
compute = 1

# Try to load results from earlier runs:
if 1:
    
    # Load scaler and pca if they exist:
    if os.path.exists("../Data_Results/Exp_12_scaler.pkl") and \
       os.path.exists("../Data_Results/Exp_12_pca.pkl"):
        
        # Load scaler:
        with open("../Data_Results/Exp_12_scaler.pkl", "rb") as f:
            scaler = pkl.load(f)
            
        # Load pca:
        with open("../Data_Results/Exp_12_pca.pkl", "rb") as f:
            ipca = pkl.load(f)
        
        
        # Change compute to 0:
        compute = 0
        
print(f"compute = {compute}")
# Out:
# compute = 0

# %%
# Compute scaler and pca:
if compute:
    
    # Fit scaler
    scaler = StandardScaler().fit(data_vals)
    
    # Transform features:
    data_vals_scaled = scaler.transform(data_vals)
    
    # Fit IncrementalPCA:
    ipca = IncrementalPCA(batch_size=250).fit(data_vals_scaled)

# %%
# Save scaler and ipca objects (in Coding/Data_Results):
if compute:
    with open("../Data_Results/Exp_12_scaler.pkl", "wb") as f:
        pkl.dump(scaler, f)

    with open("../Data_Results/Exp_12_pca.pkl", "wb") as f:
        pkl.dump(ipca, f)

# %% [markdown]
# ### Explained Variance

# %%
# Plot the PCA E.V.R:
fig1 = plt.figure(figsize=(7.5,5))
pca_x_ticks = np.arange(1, ipca.n_components_+1, 1)
plt.plot(pca_x_ticks,
         np.cumsum(ipca.explained_variance_ratio_),
         "o",
         linestyle="dashed",
         color="red")

plt.plot(pca_x_ticks,
         ipca.explained_variance_ratio_,
         "o",
         linestyle="dotted",
         color="blue")

pc_keep = np.sum(ipca.explained_variance_ > 1)

plt.vlines(pc_keep, 0, 1, colors="black", linestyles="dashed")

plt.xscale("symlog")
plt.xlabel("Number of components")
plt.ylabel("Explained variance ratio")

pca_x_gridlines = np.array([2**i for i in range(10)])

plt.xticks(pca_x_gridlines,
           [str(pca_x_gridlines[i]) \
            for i in range(len(pca_x_gridlines))])

# Set legend:
plt.legend(["Cumulative", "Individual", f"PC cutoff ({pc_keep})"],
            loc="right",
            frameon=True, fancybox=True,
            shadow=True, framealpha=1, facecolor="lightgrey")

plt.title("PCA explained variance ratio")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="750.6666666666666">

# %%
# Save figure:
fig1.savefig("../Figures/Exp_12_full_PCA_EVR.png", dpi=100)

# %% [markdown]
# ### Reconstruction vs Original

# %%
# Choose principal components:
princomps = ipca.components_[:pc_keep]

# Scale data:
data_vals_scaled = scaler.transform(data_vals)

# Transform features:
data_vals_scaled_pca = data_vals_scaled[:100] @ princomps.T

# Reconstruct features:
data_vals_scaled_recon = data_vals_scaled_pca @ princomps

# Rescale features:
data_vals_recon = scaler.inverse_transform(data_vals_scaled_recon)

# Number of plot features:
plot_feats = data_vals.shape[1] // 3

# %% [markdown]
# Surface Elevation

# %%
# Select plot times and plot data:
plot_times = [12, 22]
plot_data = data_vals[plot_times, :plot_feats]
plot_data_recon = data_vals_recon[plot_times, :plot_feats]

plot_obj = data.Surface_elevation[0].copy()
plot_rec_obj = data.Surface_elevation[0].copy()

# Create 2 by 3 subplot:
fig2, axs = plt.subplots(2, 3, figsize=(15, 10))

# Loop over the two times:
for t in range(len(plot_times)):

    # Plot the original data:
    plot_obj.values = plot_data[t]
    
    cmap_max = np.quantile(np.abs(plot_obj.values), 0.99)
    digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
    cmap_max = np.round(cmap_max, digits)
    
    plot_obj.plot(ax=axs[t,0], cmap="seismic",
                vmin = -cmap_max, vmax = cmap_max)
    axs[t,0].set_title(f"Original data @ Time: {plot_times[t]}")

    # Plot the reconstructed data:
    plot_rec_obj.values = plot_data_recon[t]
    
    cmap_max = np.quantile(np.abs(plot_rec_obj.values), 0.99)
    digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
    cmap_max = np.round(cmap_max, digits)
    
    plot_rec_obj.plot(ax=axs[t,1], cmap="seismic",
                    vmin=-cmap_max, vmax=cmap_max)
    axs[t,1].set_title(
        f"Reconstructed data @ Time: {plot_times[t]}")

    # Compute the RMSE:
    rmse_diff = mf.rmse(plot_data[t], plot_data_recon[t])

    # Plot the difference:
    plot_obj.values = plot_data[t] - plot_data_recon[t]
    
    cmap_max = np.quantile(np.abs(plot_obj.values), 0.99)
    digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
    cmap_max = np.round(cmap_max, digits)
    
    plot_obj.plot(ax=axs[t,2], cmap="seismic",
    vmin=-cmap_max, vmax=cmap_max)
    axs[t,2].set_title(f"Difference.\nRMSE: {rmse_diff:.6f}")

fig2.suptitle(f"PCA ({pc_keep}-PC) reconstruction comparison (Z)\n",
              fontsize=16)

fig2.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
fig2.savefig(f"../Figures/Exp_12_full_PCA_{pc_keep}PC_comparison_Z.png", dpi=100)

# %% [markdown]
# U-velocity

# %%
# Select plot times and plot data:
plot_times = [12, 22]

plot_data = data_vals[plot_times, plot_feats:2*plot_feats]
plot_data_recon = data_vals_recon[plot_times, plot_feats:2*plot_feats]

plot_obj = data.U_velocity[0].copy()
plot_rec_obj = data.U_velocity[0].copy()

# Create 2 by 3 subplot:
fig3, axs = plt.subplots(2, 3, figsize=(15, 10))

# Loop over the two times:
for t in range(len(plot_times)):

    # Plot the original data:
    plot_obj.values = plot_data[t]
    
    cmap_max = np.quantile(np.abs(plot_obj.values), 0.99)
    digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
    cmap_max = np.round(cmap_max, digits)
    
    plot_obj.plot(ax=axs[t,0], cmap="seismic",
                vmin = -cmap_max, vmax = cmap_max)
    axs[t,0].set_title(f"Original data @ Time: {plot_times[t]}")

    # Plot the reconstructed data:
    plot_rec_obj.values = plot_data_recon[t]
    
    cmap_max = np.quantile(np.abs(plot_rec_obj.values), 0.99)
    digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
    cmap_max = np.round(cmap_max, digits)
    
    
    plot_rec_obj.plot(ax=axs[t,1], cmap="seismic",
                    vmin = -cmap_max, vmax = cmap_max)
    axs[t,1].set_title(
        f"Reconstructed data @ Time: {plot_times[t]}")

    # Compute the RMSE:
    rmse_diff = mf.rmse(plot_data[t], plot_data_recon[t])

    # Plot the difference:
    plot_obj.values = plot_data[t] - plot_data_recon[t]
    
    cmap_max = np.quantile(np.abs(plot_obj.values), 0.99)
    digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
    cmap_max = np.round(cmap_max, digits)
    
    plot_obj.plot(ax=axs[t,2], cmap="seismic",
                vmin = -cmap_max, vmax = cmap_max)
    axs[t,2].set_title(f"Difference.\nRMSE: {rmse_diff:.6f}")

fig3.suptitle(f"PCA ({pc_keep}-PC) reconstruction comparison (U)\n",
              fontsize=16)

fig3.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
fig3.savefig(f"../Figures/Exp_12_full_PCA_{pc_keep}PC_comparison_U.png", dpi=100)

# %% [markdown]
# V-velocity

# %%
# Select plot times and plot data:
plot_times = [12, 22]
plot_data = data_vals[plot_times, 2*plot_feats:]
plot_data_recon = data_vals_recon[plot_times, 2*plot_feats:]

cmap_max_diff = np.max([plot_data, plot_data_recon]) -\
                np.min([plot_data, plot_data_recon])

plot_obj = data.V_velocity[0].copy()
plot_rec_obj = data.V_velocity[0].copy()

# Create 2 by 3 subplot:
fig4, axs = plt.subplots(2, 3, figsize=(15, 10))

# Loop over the two times:
for t in range(len(plot_times)):

    # Plot the original data:
    plot_obj.values = plot_data[t]
    
    cmap_max = np.quantile(np.abs(plot_obj.values), 0.99)
    digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
    cmap_max = np.round(cmap_max, digits)
        
    plot_obj.plot(ax=axs[t,0], cmap="seismic",
                vmin = -cmap_max, vmax = cmap_max)
    axs[t,0].set_title(f"Original data @ Time: {plot_times[t]}")

    # Plot the reconstructed data:
    plot_rec_obj.values = plot_data_recon[t]
    
    cmap_max = np.quantile(np.abs(plot_rec_obj.values), 0.99)
    digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
    cmap_max = np.round(cmap_max, digits)
    
    
    plot_rec_obj.plot(ax=axs[t,1], cmap="seismic",
                    vmin = -cmap_max, vmax = cmap_max)
    axs[t,1].set_title(
        f"Reconstructed data @ Time: {plot_times[t]}")

    # Compute the RMSE:
    rmse_diff = mf.rmse(plot_data[t], plot_data_recon[t])

    # Plot the difference:
    plot_obj.values = plot_data[t] - plot_data_recon[t]
    
    cmap_max = np.quantile(np.abs(plot_obj.values), 0.99)
    digits = np.sum([cmap_max * (10**i) < 1 for i in range(5)])
    cmap_max = np.round(cmap_max, digits)
    
    
    plot_obj.plot(ax=axs[t,2], cmap="seismic",
                    vmin = -cmap_max, vmax = cmap_max)
    axs[t,2].set_title(f"Difference.\nRMSE: {rmse_diff:.6f}")

fig4.suptitle(f"PCA ({pc_keep}-PC) reconstruction comparison (V)\n",
              fontsize=16)

fig4.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
fig4.savefig(f"../Figures/Exp_12_full_PCA_{pc_keep}PC_comparison_V.png", dpi=100)
